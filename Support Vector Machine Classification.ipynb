# %% [markdown]
# # Import library

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random
import seaborn as sns
import scipy
from scipy.stats import pearsonr

import sklearn
from sklearn import datasets, linear_model
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Load Datasets

# %%
# Please change the file path to the location that where the concrete dataset located.
# all_df=pd.read_csv("C:\Data_for_UCI_named.csv",index_col=False)
all_df=pd.read_csv("/Users/alden/Desktop/machine_learning/Data_for_UCI_named.csv",index_col=False)
all_df.head()
# Out:
#        tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0  2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1  9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2  8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3  0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4  3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
#
#          p4        g1        g2        g3        g4      stab     stabf
# 0 -1.723086  0.650456  0.859578  0.887445  0.958034  0.055347  unstable
# 1 -1.255012  0.413441  0.862414  0.562139  0.781760 -0.005957    stable
# 2 -0.920492  0.163041  0.766689  0.839444  0.109853  0.003471  unstable
# 3 -0.997374  0.446209  0.976744  0.929381  0.362718  0.028871  unstable
# 4 -0.554305  0.797110  0.455450  0.656947  0.820923  0.049860  unstable

# %%
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tau1    10000 non-null  float64
#  1   tau2    10000 non-null  float64
#  2   tau3    10000 non-null  float64
#  3   tau4    10000 non-null  float64
#  4   p1      10000 non-null  float64
#  5   p2      10000 non-null  float64
#  6   p3      10000 non-null  float64
#  7   p4      10000 non-null  float64
#  8   g1      10000 non-null  float64
#  9   g2      10000 non-null  float64
#  10  g3      10000 non-null  float64
#  11  g4      10000 non-null  float64
#  12  stab    10000 non-null  float64
#  13  stabf   10000 non-null  object
# dtypes: float64(13), object(1)
# memory usage: 1.1+ MB

# %%
all_df.describe()
# Out:
#                tau1          tau2          tau3          tau4            p1  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       5.250000      5.250001      5.250004      5.249997      3.750000
# std        2.742548      2.742549      2.742549      2.742556      0.752160
# min        0.500793      0.500141      0.500788      0.500473      1.582590
# 25%        2.874892      2.875140      2.875522      2.874950      3.218300
# 50%        5.250004      5.249981      5.249979      5.249734      3.751025
# 75%        7.624690      7.624893      7.624948      7.624838      4.282420
# max        9.999469      9.999837      9.999450      9.999443      5.864418
#
#                  p2            p3            p4            g1            g2  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      -1.250000     -1.250000     -1.250000      0.525000      0.525000
# std        0.433035      0.433035      0.433035      0.274256      0.274255
# min       -1.999891     -1.999945     -1.999926      0.050009      0.050053
# 25%       -1.624901     -1.625025     -1.624960      0.287521      0.287552
# 50%       -1.249966     -1.249974     -1.250007      0.525009      0.525003
# 75%       -0.874977     -0.875043     -0.875065      0.762435      0.762490
# max       -0.500108     -0.500072     -0.500025      0.999937      0.999944
#
#                  g3            g4          stab
# count  10000.000000  10000.000000  10000.000000
# mean       0.525000      0.525000      0.015731
# std        0.274255      0.274255      0.036919
# min        0.050054      0.050028     -0.080760
# 25%        0.287514      0.287494     -0.015557
# 50%        0.525015      0.525002      0.017142
# 75%        0.762440      0.762433      0.044878
# max        0.999982      0.999930      0.109403

# %%
# Determine the number of unstable and stable for the prediction result
all_df['stabf'].value_counts()
# Out:
# unstable    6380
# stable      3620
# Name: stabf, dtype: int64

# %%
sns.countplot(x="stabf", data=all_df)

# %%
# Visualize and detemrine the outliers in each feature
data_mean = all_df.iloc[:, :]
data_mean.plot(kind='box', subplots=True, layout=(8,4), sharex=False,
sharey=False, fontsize=12, figsize=(15,20));

# %%
fig,ax=plt.subplots(1,figsize=(20,8))
sns.boxplot(data=all_df.iloc[:, 0:13],ax=ax)

# %%
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(15,20))
fig.subplots_adjust(hspace =.2, wspace=.5)
axes = axes.ravel()
for i, col in enumerate(all_df.columns[:-2]):
    _= sns.boxplot(y=col, x='stabf', data=all_df, ax=axes[i])

# %% [markdown]
# # HeatMap

# %%
corrMatt = all_df.corr()
# Generate a mask for the upper triangle
mask = np.zeros_like(corrMatt)
mask[np.triu_indices_from(mask)] = True
# Set up the matplotlib figure
fig, ax = plt.subplots(figsize=(20, 12))
plt.title('electric grid Feature Correlation')
# Generate a custom diverging colormap
cmap = sns.diverging_palette(260, 10, as_cmap=True)
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corrMatt, vmax=1.2, square=False, cmap=cmap, mask=mask,
ax=ax, annot=True, fmt='.2g', linewidths=1);

# %% [markdown]
# # Data Cleaning and Preprocessing

# %%
# Remove the row that contain null values and duplicate data

all_df.dropna(inplace = True)
all_df.drop_duplicates(inplace = True)
all_df.shape
# Out:
# (10000, 14)

# %%
# Fucntion of determine the range of outlier based on lower and upper bound of the dataset
def outliers(df, ft):
    Q1 = df[ft].quantile(0.25)
    Q3 = df[ft].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    ls = df.index[(df[ft] < lower_bound) | (df[ft] > upper_bound)]
    
    return ls

# %%
# Function to remove the outlier that determine from the original dataset
def remove(df, ls):
    ls = sorted(set(ls))
    df = df.drop(ls)
    return df

# %%
index_list = []
for feature in ['tau1','tau2','tau3','tau4','p1','p2','p3','p4','g1','g2','g3','g4']:
    index_list.extend(outliers(all_df,feature))

# %%
all_df_cleaned = remove(all_df,index_list)

# %%
all_df_cleaned.shape
# Out:
# (9999, 14)

# %% [markdown]
# ## Normalize data

# %%
X = all_df_cleaned.drop(['stabf','stab'],axis=1)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
Xs = scaler.fit_transform(X)
fig,ax=plt.subplots(1,figsize=(20,8))
sns.boxplot(data=Xs,ax=ax)

# %% [markdown]
# ## Encode the target column to either 0 and 1 for classification

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
all_df_cleaned['stabf'] = le.fit_transform(all_df_cleaned['stabf'])
all_df.head()
# assign numerical label to y
y = all_df_cleaned['stabf']

# %% [markdown]
# # Split dataset into test and training test

# %%
# The datasets is divided into 70% train size and 30% test size
Xs_train, Xs_test, y_train, y_test = train_test_split(Xs, y, test_size=0.3, 
random_state=1, stratify=y)

# %% [markdown]
# # Default Hyperparameter of SVC model

# %%
# Only the random state is set to 1 to prevent different result obtained in every run
from sklearn.svm import SVC
clf = SVC(random_state=1)
clf.fit(Xs_train, y_train)
predict=clf.predict(Xs_test)

# %% [markdown]
# # Classification accuracy without k-fold

# %%
classifier_score = clf.score(Xs_test, y_test)
print('The classifier accuracy score is {:03.2f}'.format(classifier_score))
# Out:
# The classifier accuracy score is 0.95

# %% [markdown]
# # K-fold Cross Validation for Classification Accuracy

# %%
from sklearn.model_selection import cross_val_score
n_folds = 5
cv_error = np.average(cross_val_score(clf, Xs, y, cv=n_folds, scoring='accuracy'))
print('The {}-fold cross-validation accuracy score for this classifier is {:.2f}'.format(n_folds, cv_error))
# Out:
# The 5-fold cross-validation accuracy score for this classifier is 0.96

# %% [markdown]
# # Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [1,5,10], 
              'kernel': ['rbf','poly','linear','sigmoid'],
              'gamma':['scale','auto']}
grid_clf = GridSearchCV(clf, param_grid, refit = True, n_jobs=-1, verbose = 3)
grid_clf.fit(Xs_train, y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=SVC(random_state=1), n_jobs=-1,
#              param_grid={'C': [1, 5, 10], 'gamma': ['scale', 'auto'],
#                          'kernel': ['rbf', 'poly', 'linear', 'sigmoid']},
#              verbose=3)

# %%
# Show the best parameter that produce the highest score
print(grid_clf.best_params_)
print(grid_clf.best_estimator_)
# Out:
# {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}
# SVC(C=10, gamma='auto', random_state=1)

# %% [markdown]
# # Apply optimise hyperparameter to SVC Model

# %%
from sklearn.svm import SVC
clf = SVC(random_state=1).set_params(**grid_clf.best_params_)
# clf = SVC(C=10,kernel='rbf',gamma='auto')
clf.fit(Xs_train, y_train)
predict=clf.predict(Xs_test)

# %% [markdown]
# ## Classification accuracy without k-fold

# %%
classifier_score = clf.score(Xs_test, y_test)
print('The classifier accuracy score is {:03.2f}'.format(classifier_score))
# Out:
# The classifier accuracy score is 0.97

# %% [markdown]
# ## K-fold Cross Validation For Classification Accuracy

# %%
from sklearn.model_selection import cross_val_score
n_folds = 5
cv_error = np.average(cross_val_score(clf, Xs, y, cv=n_folds, scoring='accuracy'))
print('The {}-fold cross-validation accuracy score for this classifier is {:.2f}'.format(n_folds, cv_error))
# Out:
# The 5-fold cross-validation accuracy score for this classifier is 0.97
# [CV 5/5] END ......C=1, gamma=scale, kernel=rbf;, score=0.954 total time=   0.7s
# [CV 2/5] END ...C=1, gamma=scale, kernel=linear;, score=0.826 total time=   1.0s
# [CV 4/5] END ......C=1, gamma=auto, kernel=poly;, score=0.863 total time=   0.8s
# [CV 4/5] END ...C=1, gamma=auto, kernel=sigmoid;, score=0.751 total time=   0.6s
# [CV 1/5] END .....C=5, gamma=scale, kernel=poly;, score=0.871 total time=   1.0s
# [CV 3/5] END ..C=5, gamma=scale, kernel=sigmoid;, score=0.751 total time=   0.6s
# [CV 3/5] END .......C=5, gamma=auto, kernel=rbf;, score=0.953 total time=   0.5s
# [CV 2/5] END ....C=5, gamma=auto, kernel=linear;, score=0.826 total time=   1.5s
# [CV 1/5] END ....C=10, gamma=scale, kernel=poly;, score=0.874 total time=   1.2s
# [CV 1/5] END .C=10, gamma=scale, kernel=sigmoid;, score=0.744 total time=   0.5s
# [CV 1/5] END ......C=10, gamma=auto, kernel=rbf;, score=0.966 total time=   0.5s
# [CV 1/5] END .....C=10, gamma=auto, kernel=poly;, score=0.874 total time=   1.3s
# [CV 1/5] END ..C=10, gamma=auto, kernel=sigmoid;, score=0.740 total time=   0.5s
# [CV 2/5] END ......C=1, gamma=scale, kernel=rbf;, score=0.948 total time=   0.7s
# [CV 1/5] END ...C=1, gamma=scale, kernel=linear;, score=0.819 total time=   1.0s
# [CV 3/5] END ......C=1, gamma=auto, kernel=poly;, score=0.864 total time=   0.7s
# [CV 1/5] END ...C=1, gamma=auto, kernel=sigmoid;, score=0.751 total time=   0.7s
# [CV 1/5] END ......C=5, gamma=scale, kernel=rbf;, score=0.957 total time=   0.5s
# [CV 5/5] END .....C=5, gamma=scale, kernel=poly;, score=0.888 total time=   0.9s
# [CV 5/5] END ..C=5, gamma=scale, kernel=sigmoid;, score=0.738 total time=   0.5s
# [CV 2/5] END ......C=5, gamma=auto, kernel=poly;, score=0.893 total time=   0.8s
# [CV 2/5] END ...C=5, gamma=auto, kernel=sigmoid;, score=0.739 total time=   0.6s
# [CV 2/5] END .....C=10, gamma=scale, kernel=rbf;, score=0.958 total time=   0.5s
# [CV 2/5] END ..C=10, gamma=scale, kernel=linear;, score=0.826 total time=   2.2s
# [CV 4/5] END .....C=10, gamma=auto, kernel=poly;, score=0.889 total time=   1.1s
# [CV 2/5] END ..C=10, gamma=auto, kernel=sigmoid;, score=0.736 total time=   0.6s
# [CV 3/5] END .....C=1, gamma=scale, kernel=poly;, score=0.864 total time=   0.8s
# [CV 4/5] END ...C=1, gamma=scale, kernel=linear;, score=0.816 total time=   0.9s
# [CV 5/5] END .......C=1, gamma=auto, kernel=rbf;, score=0.955 total time=   0.7s
# [CV 5/5] END ....C=1, gamma=auto, kernel=linear;, score=0.826 total time=   0.8s
# [CV 3/5] END .....C=5, gamma=scale, kernel=poly;, score=0.886 total time=   0.9s
# [CV 2/5] END ..C=5, gamma=scale, kernel=sigmoid;, score=0.740 total time=   0.6s
# [CV 2/5] END .......C=5, gamma=auto, kernel=rbf;, score=0.958 total time=   0.5s
# [CV 5/5] END ......C=5, gamma=auto, kernel=poly;, score=0.888 total time=   0.9s
# [CV 4/5] END ...C=5, gamma=auto, kernel=sigmoid;, score=0.728 total time=   0.6s
# [CV 4/5] END .....C=10, gamma=scale, kernel=rbf;, score=0.959 total time=   0.5s
# [CV 4/5] END ..C=10, gamma=scale, kernel=linear;, score=0.815 total time=   2.0s
# [CV 3/5] END .....C=10, gamma=auto, kernel=poly;, score=0.890 total time=   1.2s
# [CV 3/5] END ..C=10, gamma=auto, kernel=sigmoid;, score=0.745 total time=   0.5s
# [CV 5/5] END .....C=1, gamma=scale, kernel=poly;, score=0.873 total time=   0.8s
# [CV 3/5] END ..C=1, gamma=scale, kernel=sigmoid;, score=0.748 total time=   0.8s
# [CV 1/5] END .......C=1, gamma=auto, kernel=rbf;, score=0.951 total time=   0.7s
# [CV 1/5] END ....C=1, gamma=auto, kernel=linear;, score=0.819 total time=   0.8s
# [CV 2/5] END ......C=5, gamma=scale, kernel=rbf;, score=0.958 total time=   0.5s
# [CV 1/5] END ...C=5, gamma=scale, kernel=linear;, score=0.819 total time=   1.4s
# [CV 5/5] END .......C=5, gamma=auto, kernel=rbf;, score=0.956 total time=   0.5s
# [CV 5/5] END ....C=5, gamma=auto, kernel=linear;, score=0.826 total time=   1.4s
# [CV 4/5] END ....C=10, gamma=scale, kernel=poly;, score=0.890 total time=   1.1s
# [CV 2/5] END .C=10, gamma=scale, kernel=sigmoid;, score=0.737 total time=   0.6s
# [CV 2/5] END ......C=10, gamma=auto, kernel=rbf;, score=0.958 total time=   0.5s
# [CV 2/5] END .....C=10, gamma=auto, kernel=poly;, score=0.894 total time=   1.4s
# [CV 5/5] END ..C=10, gamma=auto, kernel=sigmoid;, score=0.740 total time=   0.6s
# [CV 4/5] END .....C=1, gamma=scale, kernel=poly;, score=0.862 total time=   0.8s
# [CV 2/5] END ..C=1, gamma=scale, kernel=sigmoid;, score=0.747 total time=   0.8s
# [CV 2/5] END .......C=1, gamma=auto, kernel=rbf;, score=0.948 total time=   0.8s
# [CV 2/5] END ....C=1, gamma=auto, kernel=linear;, score=0.826 total time=   1.0s
# [CV 4/5] END .....C=5, gamma=scale, kernel=poly;, score=0.884 total time=   1.0s
# [CV 4/5] END ..C=5, gamma=scale, kernel=sigmoid;, score=0.739 total time=   0.6s
# [CV 4/5] END .......C=5, gamma=auto, kernel=rbf;, score=0.955 total time=   0.5s
# [CV 4/5] END ....C=5, gamma=auto, kernel=linear;, score=0.815 total time=   1.5s
# [CV 2/5] END ....C=10, gamma=scale, kernel=poly;, score=0.894 total time=   1.3s
# [CV 4/5] END .C=10, gamma=scale, kernel=sigmoid;, score=0.748 total time=   0.5s
# [CV 4/5] END ......C=10, gamma=auto, kernel=rbf;, score=0.959 total time=   0.5s
# [CV 5/5] END .....C=10, gamma=auto, kernel=poly;, score=0.886 total time=   1.3s
# [CV 4/5] END ..C=10, gamma=auto, kernel=sigmoid;, score=0.744 total time=   0.7s
# [CV 1/5] END ......C=1, gamma=scale, kernel=rbf;, score=0.951 total time=   0.8s
# [CV 5/5] END ...C=1, gamma=scale, kernel=linear;, score=0.826 total time=   1.0s
# [CV 1/5] END ......C=1, gamma=auto, kernel=poly;, score=0.856 total time=   0.7s
# [CV 4/5] END ....C=1, gamma=auto, kernel=linear;, score=0.816 total time=   0.8s
# [CV 2/5] END .....C=5, gamma=scale, kernel=poly;, score=0.891 total time=   0.8s
# [CV 1/5] END ..C=5, gamma=scale, kernel=sigmoid;, score=0.748 total time=   0.5s
# [CV 1/5] END .......C=5, gamma=auto, kernel=rbf;, score=0.957 total time=   0.5s
# [CV 1/5] END ......C=5, gamma=auto, kernel=poly;, score=0.871 total time=   0.8s
# [CV 1/5] END ...C=5, gamma=auto, kernel=sigmoid;, score=0.746 total time=   0.6s
# [CV 1/5] END .....C=10, gamma=scale, kernel=rbf;, score=0.966 total time=   0.5s
# [CV 5/5] END ....C=10, gamma=scale, kernel=poly;, score=0.886 total time=   1.2s
# [CV 5/5] END .C=10, gamma=scale, kernel=sigmoid;, score=0.739 total time=   0.7s
# [CV 5/5] END ......C=10, gamma=auto, kernel=rbf;, score=0.959 total time=   0.5s
# [CV 5/5] END ...C=10, gamma=auto, kernel=linear;, score=0.826 total time=   2.0s
# [CV 1/5] END .....C=1, gamma=scale, kernel=poly;, score=0.856 total time=   0.7s
# [CV 3/5] END ...C=1, gamma=scale, kernel=linear;, score=0.816 total time=   1.0s
# [CV 2/5] END ......C=1, gamma=auto, kernel=poly;, score=0.882 total time=   0.8s
# [CV 3/5] END ...C=1, gamma=auto, kernel=sigmoid;, score=0.751 total time=   0.7s
# [CV 3/5] END ......C=5, gamma=scale, kernel=rbf;, score=0.953 total time=   0.5s
# [CV 3/5] END ...C=5, gamma=scale, kernel=linear;, score=0.816 total time=   1.4s
# [CV 4/5] END ......C=5, gamma=auto, kernel=poly;, score=0.884 total time=   0.9s
# [CV 3/5] END ...C=5, gamma=auto, kernel=sigmoid;, score=0.751 total time=   0.6s
# [CV 3/5] END .....C=10, gamma=scale, kernel=rbf;, score=0.946 total time=   0.5s
# [CV 3/5] END ..C=10, gamma=scale, kernel=linear;, score=0.816 total time=   2.2s
# [CV 3/5] END ...C=10, gamma=auto, kernel=linear;, score=0.816 total time=   2.1s
# [CV 4/5] END ......C=1, gamma=scale, kernel=rbf;, score=0.946 total time=   0.8s
# [CV 1/5] END ..C=1, gamma=scale, kernel=sigmoid;, score=0.750 total time=   0.8s
# [CV 3/5] END .......C=1, gamma=auto, kernel=rbf;, score=0.951 total time=   0.8s
# [CV 3/5] END ....C=1, gamma=auto, kernel=linear;, score=0.816 total time=   0.8s
# [CV 4/5] END ......C=5, gamma=scale, kernel=rbf;, score=0.955 total time=   0.5s
# [CV 4/5] END ...C=5, gamma=scale, kernel=linear;, score=0.815 total time=   1.4s
# [CV 3/5] END ......C=5, gamma=auto, kernel=poly;, score=0.886 total time=   1.1s
# [CV 5/5] END ...C=5, gamma=auto, kernel=sigmoid;, score=0.740 total time=   0.6s
# [CV 5/5] END .....C=10, gamma=scale, kernel=rbf;, score=0.958 total time=   0.5s
# [CV 5/5] END ..C=10, gamma=scale, kernel=linear;, score=0.826 total time=   2.1s
# [CV 2/5] END ...C=10, gamma=auto, kernel=linear;, score=0.826 total time=   2.1s
# [CV 3/5] END ......C=1, gamma=scale, kernel=rbf;, score=0.951 total time=   0.8s
# [CV 4/5] END ..C=1, gamma=scale, kernel=sigmoid;, score=0.751 total time=   0.8s
# [CV 4/5] END .......C=1, gamma=auto, kernel=rbf;, score=0.946 total time=   0.8s
# [CV 2/5] END ...C=1, gamma=auto, kernel=sigmoid;, score=0.755 total time=   0.7s
# [CV 5/5] END ......C=5, gamma=scale, kernel=rbf;, score=0.956 total time=   0.5s
# [CV 5/5] END ...C=5, gamma=scale, kernel=linear;, score=0.826 total time=   1.6s
# [CV 3/5] END ....C=5, gamma=auto, kernel=linear;, score=0.816 total time=   1.5s
# [CV 3/5] END ....C=10, gamma=scale, kernel=poly;, score=0.889 total time=   1.3s
# [CV 3/5] END .C=10, gamma=scale, kernel=sigmoid;, score=0.744 total time=   0.6s
# [CV 3/5] END ......C=10, gamma=auto, kernel=rbf;, score=0.946 total time=   0.5s
# [CV 1/5] END ...C=10, gamma=auto, kernel=linear;, score=0.819 total time=   2.2s
# [CV 2/5] END .....C=1, gamma=scale, kernel=poly;, score=0.882 total time=   0.9s
# [CV 5/5] END ..C=1, gamma=scale, kernel=sigmoid;, score=0.738 total time=   1.0s
# [CV 5/5] END ......C=1, gamma=auto, kernel=poly;, score=0.873 total time=   0.9s
# [CV 5/5] END ...C=1, gamma=auto, kernel=sigmoid;, score=0.738 total time=   0.9s
# [CV 2/5] END ...C=5, gamma=scale, kernel=linear;, score=0.826 total time=   1.6s
# [CV 1/5] END ....C=5, gamma=auto, kernel=linear;, score=0.819 total time=   1.7s
# [CV 1/5] END ..C=10, gamma=scale, kernel=linear;, score=0.819 total time=   2.4s
# [CV 4/5] END ...C=10, gamma=auto, kernel=linear;, score=0.815 total time=   2.2s
